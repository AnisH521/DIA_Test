cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.6 MB)
#      |████████████████████████████████| 47.6 MB 27 kB/s  eta 0:00:01    |██████▏                         | 9.2 MB 5.2 MB/s eta 0:00:08     |█████████████                   | 19.2 MB 2.8 MB/s eta 0:00:11     |██████████████▎                 | 21.2 MB 2.8 MB/s eta 0:00:10     |████████████████████████████▏   | 41.9 MB 3.0 MB/s eta 0:00:02     |████████████████████████████████| 47.4 MB 608 kB/s eta 0:00:01
# Requirement already satisfied: PyYAML in ./anaconda3/lib/python3.9/site-packages (from easyocr) (6.0)
# Collecting torchvision>=0.5
#   Downloading torchvision-0.12.0-cp39-cp39-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 2.5 MB/s eta 0:00:01
# Collecting python-bidi
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: scikit-image in ./anaconda3/lib/python3.9/site-packages (from easyocr) (0.18.3)
# Requirement already satisfied: Pillow in ./anaconda3/lib/python3.9/site-packages (from easyocr) (8.4.0)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.9/site-packages (from torchvision>=0.5->easyocr) (2.26.0)
# Requirement already satisfied: typing-extensions in ./anaconda3/lib/python3.9/site-packages (from torchvision>=0.5->easyocr) (3.10.0.2)
# Requirement already satisfied: six in ./anaconda3/lib/python3.9/site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.9/site-packages (from requests->torchvision>=0.5->easyocr) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./anaconda3/lib/python3.9/site-packages (from requests->torchvision>=0.5->easyocr) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.9/site-packages (from requests->torchvision>=0.5->easyocr) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./anaconda3/lib/python3.9/site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in ./anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (3.4.3)
# Requirement already satisfied: networkx>=2.0 in ./anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (2.6.3)
# Requirement already satisfied: imageio>=2.3.0 in ./anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in ./anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in ./anaconda3/lib/python3.9/site-packages (from scikit-image->easyocr) (1.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in ./anaconda3/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in ./anaconda3/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./anaconda3/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./anaconda3/lib/python3.9/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (1.3.1)
# Installing collected packages: torch, torchvision, python-bidi, opencv-python-headless, easyocr
# Successfully installed easyocr-1.4.2 opencv-python-headless-4.5.4.60 python-bidi-0.4.2 torch-1.11.0 torchvision-0.12.0

# %%
# !wget https://labourlawadvisor.in/blog/wp-content/uploads/2019/05/pan-card-1.jpg
# Out:
# --2022-04-28 11:02:02--  https://labourlawadvisor.in/blog/wp-content/uploads/2019/05/pan-card-1.jpg
# Resolving labourlawadvisor.in (labourlawadvisor.in)... 2606:4700:3037::6815:5806, 2606:4700:3034::ac43:95e0, 172.67.149.224, ...
# Connecting to labourlawadvisor.in (labourlawadvisor.in)|2606:4700:3037::6815:5806|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31817 (31K) [image/jpeg]
# Saving to: ‘pan-card-1.jpg’
#
# pan-card-1.jpg      100%[===================>]  31.07K  --.-KB/s    in 0.01s
#
# 2022-04-28 11:02:03 (2.07 MB/s) - ‘pan-card-1.jpg’ saved [31817/31817]

# %%
import easyocr
reader = easyocr.Reader(['en','hi'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
import PIL
from PIL import ImageDraw
im = PIL.Image.open("pan-card-1.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x339 at 0x7F6C204183D0>

# %%
def draw_boxes(image, bounds, color = 'red' ,width = 1):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill = color, width = width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x339 at 0x7F6C204183D0>

# %%
final_result = reader.readtext('pan-card-1.jpg', width_ths = 1 , contrast_ths = 0.05 , decoder = 'beamsearch')
bounds
# Out:
# [([[32, 38], [218, 38], [218, 68], [32, 68]],
#   'आयकर   विभाग',
#   0.8443717784806019),
#  ([[308, 44], [472, 44], [472, 68], [308, 68]],
#   'भारत   सरकार',
#   0.17425233952080282),
#  ([[28, 74], [218, 74], [218, 100], [28, 100]],
#   'INCONE TAX DEPARIMENT',
#   0.7931108637153603),
#  ([[312, 76], [468, 76], [468, 100], [312, 100]],
#   'GOYL OF INDLA',
#   0.5191699614606536),
#  ([[41, 103], [163, 103], [163, 123], [41, 123]],
#   'D MANIKANDAN',
#   0.7526978956995414),
#  ([[39, 143], [133, 143], [133, 161], [39, 161]],
#   'DURAISANY',
#   0.6526917510770243),
#  ([[38, 180], [122, 180], [122, 200], [38, 200]],
#   '16/07/1986',
#   0.9996000984025339),
#  ([[41, 205], [205, 205], [205, 219], [41, 219]],
#   'Permanent Accouni Number',
#   0.7336708331342034),
#  ([[39, 217], [145, 217], [145, 237], [39, 237]],
#   'BNZPN12501F',
#   0.6845869756197736),
#  ([[116, 252], [166, 252], [166, 276], [116, 276]],
#   '"८Qn',
#   0.0742701068520546),
#  ([[39, 289], [99, 289], [99, 305], [39, 305]],
#   'Signature',
#   0.9379683449738951),
#  ([[457, 249], [471, 249], [471, 303], [457, 303]],
#   'ड्लै',
#   0.31684388920978335),
#  ([[164.25721864729178, 247.14304661822948],
#    [210.90531842243738, 253.3919196524136],
#    [207.74278135270822, 275.8569533817705],
#    [160.09468157756262, 269.6080803475864]],
#   '0-3*"',
#   0.060018703164263124),
#  ([[74.65465441200737, 258.5201198532081],
#    [120.78008672971733, 254.0882482603887],
#    [122.34534558799263, 272.4798801467919],
#    [76.21991327028267, 276.9117517396113]],
#   'mnr',
#   0.5525690464059541)]
